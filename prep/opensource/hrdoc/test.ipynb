# %%
import os
import cv2
import json
from glob import glob
from tqdm import tqdm
from matplotlib import pyplot as plt
from PIL import Image

# %%
HRDH_IMAGES = glob("HRDH/images/**/*.*g", recursive=True)
HRDS_IMAGES = glob("HRDS/images/**/*.*g", recursive=True)

HRDH_LABELS = glob("HRDH/t*/**/*.json", recursive=True)
HRDS_LABELS = glob("HRDS/t*/**/*.json", recursive=True)
LABEL_DICT = {}
for label in HRDH_LABELS + HRDS_LABELS:
    LABEL_DICT[os.path.basename(label).split(".json")[0]] = label

print("HRDH images:", len(HRDH_IMAGES))
print("HRDS images:", len(HRDS_IMAGES))
print("HRDH labels:", len(HRDH_LABELS))
print("HRDS labels:", len(HRDS_LABELS))
print("LABEL_DICT:", len(LABEL_DICT))
# Out:
# HRDH images: 21427
# HRDS images: 10224
# HRDH labels: 1500
# HRDS labels: 1000
# LABEL_DICT: 2500

# %%
from collections import defaultdict
def simple_page_split(data):
    
    pages = defaultdict(list)
    for item in data:
        pages[item['page']].append(item)
    
    result = {}
    
    for page_num, items in pages.items():
        page_indices = {}
        for new_idx, item in enumerate(items):
            for orig_idx, orig_item in enumerate(data):
                if (item is orig_item or
                    (item['text'] == orig_item['text'] and 
                     item['box'] == orig_item['box'] and 
                     item['page'] == orig_item['page'])):
                    page_indices[orig_idx] = new_idx
                    break
        
        # parent_id 재매핑
        remapped_items = []
        for item in items:
            new_item = item.copy()
            
            if new_item['parent_id'] == -1:
                pass 
            elif new_item['parent_id'] in page_indices:
                new_item['parent_id'] = page_indices[new_item['parent_id']]
            else:
                new_item['parent_id'] = -1
                
            remapped_items.append(new_item)
        
        result[page_num] = remapped_items
    
    return result

# %%
from datasets import Dataset

# %%
records = {
    "image_path": [],
    "label": [],
    "page": [],
    "original_path": [],
}
for image_path in tqdm(HRDH_IMAGES):
    image_path = image_path.replace("\\", "/")    
    file_ident = os.path.basename(os.path.dirname(image_path))
    label_path = LABEL_DICT.get(file_ident, None)
    if label_path is None:
        print(f"Label not found for {file_ident} in {image_path}")
        continue
    # image = cv2.imread(image_path)
    # pil_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # pil_image = Image.fromarray(pil_image).convert("RGB")
    page_num = int(os.path.basename(image_path).split(".")[0])
    with open(label_path, "r", encoding="utf-8") as f:
        label = json.load(f)

    label = simple_page_split(label).get(page_num, [])
    # image_path 절대경로
    
    records["image_path"].append(os.path.abspath(image_path).replace("\\", "/"))
    records["label"].append(label) 
    records["page"].append(page_num)
    records["original_path"].append(image_path)
# Out:
# 100%|██████████| 21427/21427 [06:34<00:00, 54.27it/s]

# %%
records
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[251], line 1
# ----> 1 records
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\core\displayhook.py:279, in DisplayHook.__call__(self, result)
#     277 self.start_displayhook()
#     278 self.write_output_prompt()
# --> 279 format_dict, md_dict = self.compute_format_data(result)
#     280 self.update_user_ns(result)
#     281 self.fill_exec_result(result)
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\core\displayhook.py:164, in DisplayHook.compute_format_data(self, result)
#     134 def compute_format_data(self, result):
#     135     """Compute format data of the object to be displayed.
#     136
#     137     The format data is a generalization of the :func:`repr` of an object.
#    (...)    162
#     163     """
# --> 164     return self.shell.display_formatter.format(result)
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\core\formatters.py:238, in DisplayFormatter.format(self, obj, include, exclude)
#     236 md = None
#     237 try:
# --> 238     data = formatter(obj)
#     239 except:
#     240     # FIXME: log the exception
#     241     raise
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\core\formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     280 """show traceback on failed format call"""
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#     285     return self._check_return(None, args[0])
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\core\formatters.py:770, in PlainTextFormatter.__call__(self, obj)
#     763 stream = StringIO()
#     764 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     765     self.max_width, self.newline,
#     766     max_seq_length=self.max_seq_length,
#     767     singleton_pprinters=self.singleton_printers,
#     768     type_pprinters=self.type_printers,
#     769     deferred_pprinters=self.deferred_printers)
# --> 770 printer.pretty(obj)
#     771 printer.flush()
#     772 return stream.getvalue()
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\lib\pretty.py:386, in RepresentationPrinter.pretty(self, obj)
#     383 for cls in _get_mro(obj_class):
#     384     if cls in self.type_pprinters:
#     385         # printer registered in self.type_pprinters
# --> 386         return self.type_pprinters[cls](obj, self, cycle)
#     387     else:
#     388         # deferred printer
#     389         printer = self._in_deferred_types(cls)
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\lib\pretty.py:693, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     691     p.pretty(key)
#     692     p.text(': ')
# --> 693     p.pretty(obj[key])
#     694 p.end_group(step, end)
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\lib\pretty.py:386, in RepresentationPrinter.pretty(self, obj)
#     383 for cls in _get_mro(obj_class):
#     384     if cls in self.type_pprinters:
#     385         # printer registered in self.type_pprinters
# --> 386         return self.type_pprinters[cls](obj, self, cycle)
#     387     else:
#     388         # deferred printer
#     389         printer = self._in_deferred_types(cls)
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\lib\pretty.py:641, in _seq_pprinter_factory.<locals>.inner(obj, p, cycle)
#     639         p.text(',')
#     640         p.breakable()
# --> 641     p.pretty(x)
#     642 if len(obj) == 1 and isinstance(obj, tuple):
#     643     # Special case for 1-item tuples.
#     644     p.text(',')
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\lib\pretty.py:386, in RepresentationPrinter.pretty(self, obj)
#     383 for cls in _get_mro(obj_class):
#     384     if cls in self.type_pprinters:
#     385         # printer registered in self.type_pprinters
# --> 386         return self.type_pprinters[cls](obj, self, cycle)
#     387     else:
#     388         # deferred printer
#     389         printer = self._in_deferred_types(cls)
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\lib\pretty.py:641, in _seq_pprinter_factory.<locals>.inner(obj, p, cycle)
#     639         p.text(',')
#     640         p.breakable()
# --> 641     p.pretty(x)
#     642 if len(obj) == 1 and isinstance(obj, tuple):
#     643     # Special case for 1-item tuples.
#     644     p.text(',')
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\lib\pretty.py:386, in RepresentationPrinter.pretty(self, obj)
#     383 for cls in _get_mro(obj_class):
#     384     if cls in self.type_pprinters:
#     385         # printer registered in self.type_pprinters
# --> 386         return self.type_pprinters[cls](obj, self, cycle)
#     387     else:
#     388         # deferred printer
#     389         printer = self._in_deferred_types(cls)
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\lib\pretty.py:693, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     691     p.pretty(key)
#     692     p.text(': ')
# --> 693     p.pretty(obj[key])
#     694 p.end_group(step, end)
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\lib\pretty.py:415, in RepresentationPrinter.pretty(self, obj)
#     413     return _default_pprint(obj, self, cycle)
#     414 finally:
# --> 415     self.end_group()
#     416     self.stack.pop()
#
# File c:\Users\korea\.conda\envs\workspace\Lib\site-packages\IPython\lib\pretty.py:300, in PrettyPrinter.end_group(self, dedent, close)
#     298 """End a group. See `begin_group` for more details."""
#     299 self.indentation -= dedent
# --> 300 group = self.group_stack.pop()
#     301 if not group.breakables:
#     302     self.group_queue.remove(group)
#
# KeyboardInterrupt:

# %%
from datasets import load
ds_ = load_from_disk("W:/datalake/staging/pending/hrdoc_raw_image_60394d56_20250623151052_unknown")

# %%
for image_path in tqdm(HRDS_IMAGES):
    image_path = image_path.replace("\\", "/")    
    file_ident = os.path.basename(os.path.dirname(image_path))
    label_path = LABEL_DICT.get(file_ident, None)
    if label_path is None:
        print(f"Label not found for {file_ident} in {image_path}")
        continue
    # image = cv2.imread(image_path)
    # pil_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    # pil_image = Image.fromarray(pil_image).convert("RGB")
    page_num = int(os.path.basename(image_path).rsplit(".")[-2].split("_")[-1])
    with open(label_path, "r", encoding="utf-8") as f:
        label = json.load(f)

    label = simple_page_split(label).get(page_num, [])
    # for idx, info in enumerate(label):
    #     box = info["box"]
    #     text = info["text"]
    #     cls_ = info["class"]
        
        
    #     cv2.rectangle(image, (box[0], box[1]), (box[2], box[3]), (0, 255, 0), 1)
    #     cv2.putText(image, f"{idx}", (box[0], box[1] - 10), 
    #                 cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 1)
    records["image_path"].append(image_path)
    records["label"].append(label) 
    records["page"].append(page_num)
    records["original_path"].append(image_path)
# Out:
# 100%|██████████| 10224/10224 [03:47<00:00, 44.89it/s]

# %%
ds = Dataset.from_dict(records)

# %%
# image_path를 전부 image로 변환
def image_to_pil(image_path):
    from PIL import Image
    pil_image = Image.open(image_path).convert("RGB")
    # 'image'에 저장
    return {"image": pil_image}

image_ds = ds.map(image_to_pil, 
                    input_columns=["image_path"],
                    remove_columns=["image_path"],
                    num_proc=16,
                    batch_size=512,
)
# Out:
# Map (num_proc=16): 100%|██████████| 31651/31651 [02:03<00:00, 256.04 examples/s]

# %%
image_ds.save_to_disk("HRDH_HRDS_dataset",
                        storage_options={"use_tracing": False, "use_compression": True})
# Out:
# Saving the dataset (11/11 shards): 100%|██████████| 31651/31651 [00:07<00:00, 3982.67 examples/s]

# %%
label
# Out:
# [{'text': 'EXPLORING THE “RUBIK’S MAGIC” UNIVERSE',
#   'box': [159, 150, 435, 160],
#   'class': 'title',
#   'page': 0,
#   'is_meta': True,
#   'parent_id': -1,
#   'relation': 'meta'},
#  {'text': 'MAURIZIO PAOLINI',
#   'box': [256, 182, 338, 190],
#   'class': 'author',
#   'page': 0,
#   'is_meta': True,
#   'parent_id': -1,
#   'relation': 'meta'},
#  {'text': 'Abstract. By using two different invariants for the Rubik’s Magic puzzle,',
#   'box': [154, 208, 441, 218],
#   'class': 'fstline',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': -1,
#   'relation': 'contain'},
#  {'text': 'one of metric type, the other of top ological type, we can dramatically reduce',
#   'box': [154, 220, 441, 227],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 2,
#   'relation': 'connect'},
#  {'text': 'the universe of constructible configurations of the puzzle. Finding the set',
#   'box': [154, 229, 441, 237],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 3,
#   'relation': 'connect'},
#  {'text': 'of actually constructible shapes remains however a challenging task, that we',
#   'box': [154, 239, 441, 247],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 4,
#   'relation': 'connect'},
#  {'text': 'tackle by first reducing the target shapes to specific configurations: the oc-',
#   'box': [154, 249, 441, 257],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 5,
#   'relation': 'connect'},
#  {'text': 'tominoid 3D shapes, with all tiles parallel to one co ordinate plane; and the',
#   'box': [154, 259, 441, 267],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 6,
#   'relation': 'connect'},
#  {'text': 'planar “face-up” shapes, with all tiles (considered of infinitesimal width) lying',
#   'box': [154, 269, 441, 277],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 7,
#   'relation': 'connect'},
#  {'text': 'in a common plane and without sup erp osed consecutive tiles. There are still',
#   'box': [154, 279, 441, 287],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 8,
#   'relation': 'connect'},
#  {'text': 'plenty of interesting configurations that do not belong to either of these two',
#   'box': [154, 289, 441, 297],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 9,
#   'relation': 'connect'},
#  {'text': 'collections. The set of constructible configurations (those that can b e obtained',
#   'box': [154, 299, 441, 307],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 10,
#   'relation': 'connect'},
#  {'text': 'by manipulation of the undecorated puzzle from the starting situation) is a',
#   'box': [154, 309, 441, 317],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 11,
#   'relation': 'connect'},
#  {'text': 'subset of the set of configurations with vanishing invariants. We were able to',
#   'box': [154, 319, 441, 327],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 12,
#   'relation': 'connect'},
#  {'text': 'actually construct all octominoid shapes with vanishing invariants and most of',
#   'box': [154, 329, 441, 337],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 13,
#   'relation': 'connect'},
#  {'text': 'the planar “face-up” configurations. Particularly imp ortant is the topological',
#   'box': [154, 339, 441, 347],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 14,
#   'relation': 'connect'},
#  {'text': 'invariant, of which we recently found mention in [7] by Tom Verhoeff.',
#   'box': [154, 349, 412, 357],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 15,
#   'relation': 'connect'},
#  {'text': '1. Introduction',
#   'box': [257, 395, 337, 407],
#   'class': 'sec1',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': -1,
#   'relation': 'contain'},
#  {'text': 'The Rubik’s Magic is another creation of Ern˝o Rubik, the brilliant hungarian',
#   'box': [130, 415, 476, 425],
#   'class': 'fstline',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 17,
#   'relation': 'contain'},
#  {'text': 'inventor of the ubiquitous “cube” that is named after him. The Rubik’s Magic',
#   'box': [118, 427, 476, 437],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 18,
#   'relation': 'connect'},
#  {'text': 'puzzle is much less known and not very widespread today, however it is a really',
#   'box': [118, 439, 476, 449],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 19,
#   'relation': 'connect'},
#  {'text': 'surprising ob ject that hides aspects which makes it quite an interesting sub ject for',
#   'box': [118, 451, 476, 461],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 20,
#   'relation': 'connect'},
#  {'text': 'a mathematical analysis on more than one level.',
#   'box': [118, 463, 329, 473],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 21,
#   'relation': 'connect'},
#  {'text': 'We investigate here two different invariants that can be used to prove the un-',
#   'box': [130, 475, 476, 485],
#   'class': 'fstline',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 18,
#   'relation': 'equality'},
#  {'text': 'reachability of many spatial configurations of the puzzle, one of these invariants,',
#   'box': [118, 487, 476, 497],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 23,
#   'relation': 'connect'},
#  {'text': 'of topological typ e, is to our knowledge never b een extensively studied before,',
#   'box': [118, 499, 476, 509],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 24,
#   'relation': 'connect'},
#  {'text': 'although it is presumably the same mentioned in [7], and allows to significantly re-',
#   'box': [118, 511, 476, 521],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 25,
#   'relation': 'connect'},
#  {'text': 'duce the number of theoretically constructible shapes. However even in the special',
#   'box': [118, 523, 476, 533],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 26,
#   'relation': 'connect'},
#  {'text': 'case of planar “face-up” configurations (see Section 8) we don’t know whether the',
#   'box': [118, 535, 476, 545],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 27,
#   'relation': 'connect'},
#  {'text': 'combination of the two invariants, together with basic constraints coming from the',
#   'box': [118, 547, 476, 557],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 28,
#   'relation': 'connect'},
#  {'text': 'mechanics of the puzzle, is complete, i.e. if it characterizes the set of constructible',
#   'box': [118, 559, 476, 569],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 29,
#   'relation': 'connect'},
#  {'text': 'configurations. Indeed there are still a few planar face-up configurations having',
#   'box': [118, 571, 476, 581],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 30,
#   'relation': 'connect'},
#  {'text': 'b oth vanishing invariants, but that we are not able to construct. In this sense this',
#   'box': [118, 583, 476, 593],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 31,
#   'relation': 'connect'},
#  {'text': 'Rubik’s invention remains an interesting sub ject of mathematical analysis.',
#   'box': [118, 595, 443, 604],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 32,
#   'relation': 'connect'},
#  {'text': 'In Section 2 we describe the puzzle and discuss its mechanics, the lo cal con-',
#   'box': [130, 606, 476, 616],
#   'class': 'fstline',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 23,
#   'relation': 'equality'},
#  {'text': 'straints are discussed in Section 3. The addition of a ribbon (Section 4) allows to',
#   'box': [118, 618, 476, 628],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 34,
#   'relation': 'connect'},
#  {'text': 'introduce the two invariants, the metric and the topological invariants, describ ed',
#   'box': [118, 630, 476, 640],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 35,
#   'relation': 'connect'},
#  {'text': 'respectively in Sections 5 and 6.',
#   'box': [118, 642, 258, 652],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 36,
#   'relation': 'connect'},
#  {'text': 'The set of octominoid shapes (all tiles are parallel to a co ordinate plane and',
#   'box': [130, 654, 476, 664],
#   'class': 'fstline',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 34,
#   'relation': 'equality'},
#  {'text': 'no two of them are sup erposed) is described in Section 7. There are a total of',
#   'box': [118, 666, 476, 676],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 38,
#   'relation': 'connect'},
#  {'text': '460 distinct octominoid configurations of the undecorated puzzle with vanishing',
#   'box': [118, 678, 476, 688],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 39,
#   'relation': 'connect'},
#  {'text': 'invariants and all of them are actually contructible with the real puzzle [4, 3D',
#   'box': [118, 690, 476, 700],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 40,
#   'relation': 'connect'},
#  {'text': 'octominoids] meaning that within this special class of shap es the two invariants are',
#   'box': [118, 702, 476, 712],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 41,
#   'relation': 'connect'},
#  {'text': 'complete.',
#   'box': [118, 714, 159, 724],
#   'class': 'para',
#   'page': 0,
#   'is_meta': False,
#   'parent_id': 42,
#   'relation': 'connect'},
#  {'text': 'Date : July 22, 2022.',
#   'box': [130, 740, 205, 748],
#   'class': 'fnote',
#   'page': 0,
#   'is_meta': True,
#   'parent_id': -1,
#   'relation': 'meta'},
#  {'text': '1',
#   'box': [295, 753, 299, 760],
#   'class': 'foot',
#   'page': 0,
#   'is_meta': True,
#   'parent_id': -1,
#   'relation': 'meta'}]

# %%
image_path
# Out:
# 'HRDH/images\\1401.3699\\0.png'

# %%
LABEL_DICT
# Out:
# {'1401.3699': 'HRDH\\test\\1401.3699.json',
#  '1402.2741': 'HRDH\\test\\1402.2741.json',
#  '1406.1682': 'HRDH\\test\\1406.1682.json',
#  '1410.8366': 'HRDH\\test\\1410.8366.json',
#  '1411.3334': 'HRDH\\test\\1411.3334.json',
#  '1412.1395': 'HRDH\\test\\1412.1395.json',
#  '1412.7419': 'HRDH\\test\\1412.7419.json',
#  '1412.7854': 'HRDH\\test\\1412.7854.json',
#  '1501.04826': 'HRDH\\test\\1501.04826.json',
#  '1502.00973': 'HRDH\\test\\1502.00973.json',
#  '1503.05697': 'HRDH\\test\\1503.05697.json',
#  '1503.07150': 'HRDH\\test\\1503.07150.json',
#  '1504.07339': 'HRDH\\test\\1504.07339.json',
#  '1504.08093': 'HRDH\\test\\1504.08093.json',
#  '1505.02091': 'HRDH\\test\\1505.02091.json',
#  '1505.07717': 'HRDH\\test\\1505.07717.json',
#  '1506.04787': 'HRDH\\test\\1506.04787.json',
#  '1506.06314': 'HRDH\\test\\1506.06314.json',
#  '1507.01067': 'HRDH\\test\\1507.01067.json',
#  '1507.01439': 'HRDH\\test\\1507.01439.json',
#  '1507.01715': 'HRDH\\test\\1507.01715.json',
#  '1507.02346': 'HRDH\\test\\1507.02346.json',
#  '1507.02354': 'HRDH\\test\\1507.02354.json',
#  '1508.00801': 'HRDH\\test\\1508.00801.json',
#  '1508.01453': 'HRDH\\test\\1508.01453.json',
#  '1508.01549': 'HRDH\\test\\1508.01549.json',
#  '1508.01984': 'HRDH\\test\\1508.01984.json',
#  '1508.03928': 'HRDH\\test\\1508.03928.json',
#  '1508.04029': 'HRDH\\test\\1508.04029.json',
#  '1508.07482': 'HRDH\\test\\1508.07482.json',
#  '1508.07509': 'HRDH\\test\\1508.07509.json',
#  '1509.00488': 'HRDH\\test\\1509.00488.json',
#  '1509.03888': 'HRDH\\test\\1509.03888.json',
#  '1509.04265': 'HRDH\\test\\1509.04265.json',
#  '1412.6334': 'HRDH\\train\\1412.6334.json',
#  '1412.7459': 'HRDH\\train\\1412.7459.json',
#  '1501.03380': 'HRDH\\train\\1501.03380.json',
#  '1501.04505': 'HRDH\\train\\1501.04505.json',
#  '1502.00842': 'HRDH\\train\\1502.00842.json',
#  '1502.03114': 'HRDH\\train\\1502.03114.json',
#  '1502.05148': 'HRDH\\train\\1502.05148.json',
#  '1502.07734': 'HRDH\\train\\1502.07734.json',
#  '1503.03465': 'HRDH\\train\\1503.03465.json',
#  '1503.03754': 'HRDH\\train\\1503.03754.json',
#  '1503.06300': 'HRDH\\train\\1503.06300.json',
#  '1503.08079': 'HRDH\\train\\1503.08079.json',
#  '1504.00636': 'HRDH\\train\\1504.00636.json',
#  '1504.01674': 'HRDH\\train\\1504.01674.json',
#  '1504.03407': 'HRDH\\train\\1504.03407.json',
#  '1504.03831': 'HRDH\\train\\1504.03831.json',
#  '1504.05573': 'HRDH\\train\\1504.05573.json',
#  '1505.02491': 'HRDH\\train\\1505.02491.json',
#  '1505.06431': 'HRDH\\train\\1505.06431.json',
#  '1506.01743': 'HRDH\\train\\1506.01743.json',
#  '1506.02076': 'HRDH\\train\\1506.02076.json',
#  '1506.03156': 'HRDH\\train\\1506.03156.json',
#  '1506.05155': 'HRDH\\train\\1506.05155.json',
#  '1506.07361': 'HRDH\\train\\1506.07361.json',
#  '1506.07569': 'HRDH\\train\\1506.07569.json',
#  '1506.07959': 'HRDH\\train\\1506.07959.json',
#  '1506.07964': 'HRDH\\train\\1506.07964.json',
#  '1506.08111': 'HRDH\\train\\1506.08111.json',
#  '1507.01285': 'HRDH\\train\\1507.01285.json',
#  '1507.02188': 'HRDH\\train\\1507.02188.json',
#  '1507.02546': 'HRDH\\train\\1507.02546.json',
#  '1507.03613': 'HRDH\\train\\1507.03613.json',
#  '1507.05814': 'HRDH\\train\\1507.05814.json',
#  '1507.06380': 'HRDH\\train\\1507.06380.json',
#  '1507.06856': 'HRDH\\train\\1507.06856.json',
#  '1507.07627': 'HRDH\\train\\1507.07627.json',
#  '1507.08186': 'HRDH\\train\\1507.08186.json',
#  '1507.08565': 'HRDH\\train\\1507.08565.json',
#  '1508.00136': 'HRDH\\train\\1508.00136.json',
#  '1508.00158': 'HRDH\\train\\1508.00158.json',
#  '1508.00382': 'HRDH\\train\\1508.00382.json',
#  '1508.01127': 'HRDH\\train\\1508.01127.json',
#  '1508.01592': 'HRDH\\train\\1508.01592.json',
#  '1508.06152': 'HRDH\\train\\1508.06152.json',
#  '1508.06618': 'HRDH\\train\\1508.06618.json',
#  '1508.07444': 'HRDH\\train\\1508.07444.json',
#  '1509.00850': 'HRDH\\train\\1509.00850.json',
#  '1509.01241': 'HRDH\\train\\1509.01241.json',
#  '1509.01304': 'HRDH\\train\\1509.01304.json',
#  '1509.01649': 'HRDH\\train\\1509.01649.json',
#  '1509.02224': 'HRDH\\train\\1509.02224.json',
#  '1509.03901': 'HRDH\\train\\1509.03901.json',
#  '1509.03929': 'HRDH\\train\\1509.03929.json',
#  '1509.04473': 'HRDH\\train\\1509.04473.json',
#  '1509.04579': 'HRDH\\train\\1509.04579.json',
#  '1509.05363': 'HRDH\\train\\1509.05363.json',
#  '1509.07234': 'HRDH\\train\\1509.07234.json',
#  '1509.07299': 'HRDH\\train\\1509.07299.json',
#  '1509.07520': 'HRDH\\train\\1509.07520.json',
#  '1509.07700': 'HRDH\\train\\1509.07700.json',
#  '1509.08421': 'HRDH\\train\\1509.08421.json',
#  '1510.00249': 'HRDH\\train\\1510.00249.json',
#  '1510.00286': 'HRDH\\train\\1510.00286.json',
#  '1510.00313': 'HRDH\\train\\1510.00313.json',
#  '1510.00436': 'HRDH\\train\\1510.00436.json',
#  '1510.02892': 'HRDH\\train\\1510.02892.json',
#  '1510.03272': 'HRDH\\train\\1510.03272.json',
#  '1510.04031': 'HRDH\\train\\1510.04031.json',
#  '1510.04404': 'HRDH\\train\\1510.04404.json',
#  '1510.04997': 'HRDH\\train\\1510.04997.json',
#  '1510.05491': 'HRDH\\train\\1510.05491.json',
#  '1510.06503': 'HRDH\\train\\1510.06503.json',
#  '1510.07816': 'HRDH\\train\\1510.07816.json',
#  '1510.08417': 'HRDH\\train\\1510.08417.json',
#  '1511.00067': 'HRDH\\train\\1511.00067.json',
#  '1511.01176': 'HRDH\\train\\1511.01176.json',
#  '1511.01306': 'HRDH\\train\\1511.01306.json',
#  '1511.02729': 'HRDH\\train\\1511.02729.json',
#  '1511.03765': 'HRDH\\train\\1511.03765.json',
#  '1511.05373': 'HRDH\\train\\1511.05373.json',
#  '1511.05438': 'HRDH\\train\\1511.05438.json',
#  '1511.05691': 'HRDH\\train\\1511.05691.json',
#  '1511.06344': 'HRDH\\train\\1511.06344.json',
#  '1511.06408': 'HRDH\\train\\1511.06408.json',
#  '1512.00272': 'HRDH\\train\\1512.00272.json',
#  '1512.01274': 'HRDH\\train\\1512.01274.json',
#  '1512.01805': 'HRDH\\train\\1512.01805.json',
#  '1512.02080': 'HRDH\\train\\1512.02080.json',
#  '1512.02833': 'HRDH\\train\\1512.02833.json',
#  '1512.02968': 'HRDH\\train\\1512.02968.json',
#  '1512.04418': 'HRDH\\train\\1512.04418.json',
#  '1512.05315': 'HRDH\\train\\1512.05315.json',
#  '1512.05433': 'HRDH\\train\\1512.05433.json',
#  '1512.05503': 'HRDH\\train\\1512.05503.json',
#  '1512.07174': 'HRDH\\train\\1512.07174.json',
#  '1601.00289': 'HRDH\\train\\1601.00289.json',
#  '1601.01345': 'HRDH\\train\\1601.01345.json',
#  '1601.01399': 'HRDH\\train\\1601.01399.json',
#  '1601.01556': 'HRDH\\train\\1601.01556.json',
#  '1601.01607': 'HRDH\\train\\1601.01607.json',
#  '1601.02075': 'HRDH\\train\\1601.02075.json',
#  '1601.02132': 'HRDH\\train\\1601.02132.json',
#  '1601.02327': 'HRDH\\train\\1601.02327.json',
#  '1601.02820': 'HRDH\\train\\1601.02820.json',
#  '1601.05872': 'HRDH\\train\\1601.05872.json',
#  '1601.07288': 'HRDH\\train\\1601.07288.json',
#  '1601.07816': 'HRDH\\train\\1601.07816.json',
#  '1601.08116': 'HRDH\\train\\1601.08116.json',
#  '1601.08162': 'HRDH\\train\\1601.08162.json',
#  '1602.01007': 'HRDH\\train\\1602.01007.json',
#  '1602.01887': 'HRDH\\train\\1602.01887.json',
#  '1602.01982': 'HRDH\\train\\1602.01982.json',
#  '1602.02142': 'HRDH\\train\\1602.02142.json',
#  '1602.02783': 'HRDH\\train\\1602.02783.json',
#  '1602.03413': 'HRDH\\train\\1602.03413.json',
#  '1602.03681': 'HRDH\\train\\1602.03681.json',
#  '1602.04568': 'HRDH\\train\\1602.04568.json',
#  '1602.05010': 'HRDH\\train\\1602.05010.json',
#  '1602.05209': 'HRDH\\train\\1602.05209.json',
#  '1602.06380': 'HRDH\\train\\1602.06380.json',
#  '1602.08426': 'HRDH\\train\\1602.08426.json',
#  '1603.00069': 'HRDH\\train\\1603.00069.json',
#  '1603.00441': 'HRDH\\train\\1603.00441.json',
#  '1603.01143': 'HRDH\\train\\1603.01143.json',
#  '1603.01170': 'HRDH\\train\\1603.01170.json',
#  '1603.01564': 'HRDH\\train\\1603.01564.json',
#  '1603.01863': 'HRDH\\train\\1603.01863.json',
#  '1603.01987': 'HRDH\\train\\1603.01987.json',
#  '1603.02211': 'HRDH\\train\\1603.02211.json',
#  '1603.03301': 'HRDH\\train\\1603.03301.json',
#  '1603.03315': 'HRDH\\train\\1603.03315.json',
#  '1603.03929': 'HRDH\\train\\1603.03929.json',
#  '1603.04150': 'HRDH\\train\\1603.04150.json',
#  '1603.04787': 'HRDH\\train\\1603.04787.json',
#  '1603.05816': 'HRDH\\train\\1603.05816.json',
#  '1603.05930': 'HRDH\\train\\1603.05930.json',
#  '1603.06035': 'HRDH\\train\\1603.06035.json',
#  '1603.06127': 'HRDH\\train\\1603.06127.json',
#  '1603.06528': 'HRDH\\train\\1603.06528.json',
#  '1603.07635': 'HRDH\\train\\1603.07635.json',
#  '1603.08120': 'HRDH\\train\\1603.08120.json',
#  '1603.08124': 'HRDH\\train\\1603.08124.json',
#  '1603.08869': 'HRDH\\train\\1603.08869.json',
#  '1603.09445': 'HRDH\\train\\1603.09445.json',
#  '1604.01496': 'HRDH\\train\\1604.01496.json',
#  '1604.01574': 'HRDH\\train\\1604.01574.json',
#  '1604.01692': 'HRDH\\train\\1604.01692.json',
#  '1604.02788': 'HRDH\\train\\1604.02788.json',
#  '1604.03593': 'HRDH\\train\\1604.03593.json',
#  '1604.03639': 'HRDH\\train\\1604.03639.json',
#  '1604.03713': 'HRDH\\train\\1604.03713.json',
#  '1604.03850': 'HRDH\\train\\1604.03850.json',
#  '1604.04506': 'HRDH\\train\\1604.04506.json',
#  '1604.05470': 'HRDH\\train\\1604.05470.json',
#  '1604.06575': 'HRDH\\train\\1604.06575.json',
#  '1604.08189': 'HRDH\\train\\1604.08189.json',
#  '1604.08516': 'HRDH\\train\\1604.08516.json',
#  '1604.08781': 'HRDH\\train\\1604.08781.json',
#  '1604.08865': 'HRDH\\train\\1604.08865.json',
#  '1605.01077': 'HRDH\\train\\1605.01077.json',
#  '1605.01799': 'HRDH\\train\\1605.01799.json',
#  '1605.02784': 'HRDH\\train\\1605.02784.json',
#  '1605.03284': 'HRDH\\train\\1605.03284.json',
#  '1605.03294': 'HRDH\\train\\1605.03294.json',
#  '1605.03453': 'HRDH\\train\\1605.03453.json',
#  '1605.03626': 'HRDH\\train\\1605.03626.json',
#  '1605.04669': 'HRDH\\train\\1605.04669.json',
#  '1605.04756': 'HRDH\\train\\1605.04756.json',
#  '1605.04941': 'HRDH\\train\\1605.04941.json',
#  '1605.06043': 'HRDH\\train\\1605.06043.json',
#  '1605.08001': 'HRDH\\train\\1605.08001.json',
#  '1605.08036': 'HRDH\\train\\1605.08036.json',
#  '1605.08374': 'HRDH\\train\\1605.08374.json',
#  '1605.08575': 'HRDH\\train\\1605.08575.json',
#  '1605.08663': 'HRDH\\train\\1605.08663.json',
#  '1605.08905': 'HRDH\\train\\1605.08905.json',
#  '1605.09757': 'HRDH\\train\\1605.09757.json',
#  '1606.01501': 'HRDH\\train\\1606.01501.json',
#  '1606.02052': 'HRDH\\train\\1606.02052.json',
#  '1606.04277': 'HRDH\\train\\1606.04277.json',
#  '1606.04630': 'HRDH\\train\\1606.04630.json',
#  '1606.04986': 'HRDH\\train\\1606.04986.json',
#  '1606.06140': 'HRDH\\train\\1606.06140.json',
#  '1606.06361': 'HRDH\\train\\1606.06361.json',
#  '1606.06581': 'HRDH\\train\\1606.06581.json',
#  '1606.07241': 'HRDH\\train\\1606.07241.json',
#  '1606.07279': 'HRDH\\train\\1606.07279.json',
#  '1606.07906': 'HRDH\\train\\1606.07906.json',
#  '1606.08008': 'HRDH\\train\\1606.08008.json',
#  '1606.08946': 'HRDH\\train\\1606.08946.json',
#  '1606.09562': 'HRDH\\train\\1606.09562.json',
#  '1607.00321': 'HRDH\\train\\1607.00321.json',
#  '1607.00440': 'HRDH\\train\\1607.00440.json',
#  '1607.00833': 'HRDH\\train\\1607.00833.json',
#  '1607.01669': 'HRDH\\train\\1607.01669.json',
#  '1607.02184': 'HRDH\\train\\1607.02184.json',
#  '1607.02444': 'HRDH\\train\\1607.02444.json',
#  '1607.03341': 'HRDH\\train\\1607.03341.json',
#  '1607.04494': 'HRDH\\train\\1607.04494.json',
#  '1607.04703': 'HRDH\\train\\1607.04703.json',
#  '1607.05171': 'HRDH\\train\\1607.05171.json',
#  '1607.05258': 'HRDH\\train\\1607.05258.json',
#  '1607.05971': 'HRDH\\train\\1607.05971.json',
#  '1607.06303': 'HRDH\\train\\1607.06303.json',
#  '1607.06946': 'HRDH\\train\\1607.06946.json',
#  '1607.07666': 'HRDH\\train\\1607.07666.json',
#  '1607.07737': 'HRDH\\train\\1607.07737.json',
#  '1608.00146': 'HRDH\\train\\1608.00146.json',
#  '1608.00280': 'HRDH\\train\\1608.00280.json',
#  '1608.00332': 'HRDH\\train\\1608.00332.json',
#  '1608.01014': 'HRDH\\train\\1608.01014.json',
#  '1608.01677': 'HRDH\\train\\1608.01677.json',
#  '1608.02111': 'HRDH\\train\\1608.02111.json',
#  '1608.02341': 'HRDH\\train\\1608.02341.json',
#  '1608.02449': 'HRDH\\train\\1608.02449.json',
#  '1608.03079': 'HRDH\\train\\1608.03079.json',
#  '1608.03087': 'HRDH\\train\\1608.03087.json',
#  '1608.03113': 'HRDH\\train\\1608.03113.json',
#  '1608.03120': 'HRDH\\train\\1608.03120.json',
#  '1608.03192': 'HRDH\\train\\1608.03192.json',
#  '1608.03206': 'HRDH\\train\\1608.03206.json',
#  '1608.04301': 'HRDH\\train\\1608.04301.json',
#  '1608.04517': 'HRDH\\train\\1608.04517.json',
#  '1608.04571': 'HRDH\\train\\1608.04571.json',
#  '1608.04904': 'HRDH\\train\\1608.04904.json',
#  '1608.05044': 'HRDH\\train\\1608.05044.json',
#  '1608.05180': 'HRDH\\train\\1608.05180.json',
#  '1608.06134': 'HRDH\\train\\1608.06134.json',
#  '1608.06412': 'HRDH\\train\\1608.06412.json',
#  '1608.07232': 'HRDH\\train\\1608.07232.json',
#  '1608.07989': 'HRDH\\train\\1608.07989.json',
#  '1608.08021': 'HRDH\\train\\1608.08021.json',
#  '1608.08162': 'HRDH\\train\\1608.08162.json',
#  '1608.08262': 'HRDH\\train\\1608.08262.json',
#  '1608.08614': 'HRDH\\train\\1608.08614.json',
#  '1608.08919': 'HRDH\\train\\1608.08919.json',
#  '1609.00131': 'HRDH\\train\\1609.00131.json',
#  '1609.01006': 'HRDH\\train\\1609.01006.json',
#  '1609.01397': 'HRDH\\train\\1609.01397.json',
#  '1609.02001': 'HRDH\\train\\1609.02001.json',
#  '1609.02015': 'HRDH\\train\\1609.02015.json',
#  '1609.02236': 'HRDH\\train\\1609.02236.json',
#  '1609.02667': 'HRDH\\train\\1609.02667.json',
#  '1609.02931': 'HRDH\\train\\1609.02931.json',
#  '1609.03825': 'HRDH\\train\\1609.03825.json',
#  '1609.04214': 'HRDH\\train\\1609.04214.json',
#  '1609.04459': 'HRDH\\train\\1609.04459.json',
#  '1609.04614': 'HRDH\\train\\1609.04614.json',
#  '1609.04994': 'HRDH\\train\\1609.04994.json',
#  '1609.06656': 'HRDH\\train\\1609.06656.json',
#  '1609.06847': 'HRDH\\train\\1609.06847.json',
#  '1609.07052': 'HRDH\\train\\1609.07052.json',
#  '1609.07391': 'HRDH\\train\\1609.07391.json',
#  '1609.07625': 'HRDH\\train\\1609.07625.json',
#  '1609.07937': 'HRDH\\train\\1609.07937.json',
#  '1609.08458': 'HRDH\\train\\1609.08458.json',
#  '1609.09221': 'HRDH\\train\\1609.09221.json',
#  '1609.09405': 'HRDH\\train\\1609.09405.json',
#  '1610.00373': 'HRDH\\train\\1610.00373.json',
#  '1610.00406': 'HRDH\\train\\1610.00406.json',
#  '1610.00830': 'HRDH\\train\\1610.00830.json',
#  '1610.01439': 'HRDH\\train\\1610.01439.json',
#  '1610.01481': 'HRDH\\train\\1610.01481.json',
#  '1610.01683': 'HRDH\\train\\1610.01683.json',
#  '1610.02754': 'HRDH\\train\\1610.02754.json',
#  '1610.03321': 'HRDH\\train\\1610.03321.json',
#  '1610.03582': 'HRDH\\train\\1610.03582.json',
#  '1610.04644': 'HRDH\\train\\1610.04644.json',
#  '1610.05072': 'HRDH\\train\\1610.05072.json',
#  '1610.05105': 'HRDH\\train\\1610.05105.json',
#  '1610.05945': 'HRDH\\train\\1610.05945.json',
#  '1610.06235': 'HRDH\\train\\1610.06235.json',
#  '1610.06292': 'HRDH\\train\\1610.06292.json',
#  '1610.06612': 'HRDH\\train\\1610.06612.json',
#  '1610.07774': 'HRDH\\train\\1610.07774.json',
#  '1610.07809': 'HRDH\\train\\1610.07809.json',
#  '1610.08429': 'HRDH\\train\\1610.08429.json',
#  '1610.08431': 'HRDH\\train\\1610.08431.json',
#  '1610.08450': 'HRDH\\train\\1610.08450.json',
#  '1610.08815': 'HRDH\\train\\1610.08815.json',
#  '1610.09612': 'HRDH\\train\\1610.09612.json',
#  '1611.00138': 'HRDH\\train\\1611.00138.json',
#  '1611.00354': 'HRDH\\train\\1611.00354.json',
#  '1611.00472': 'HRDH\\train\\1611.00472.json',
#  '1611.00484': 'HRDH\\train\\1611.00484.json',
#  '1611.00634': 'HRDH\\train\\1611.00634.json',
#  '1611.00945': 'HRDH\\train\\1611.00945.json',
#  '1611.01972': 'HRDH\\train\\1611.01972.json',
#  '1611.02274': 'HRDH\\train\\1611.02274.json',
#  '1611.02473': 'HRDH\\train\\1611.02473.json',
#  '1611.02508': 'HRDH\\train\\1611.02508.json',
#  '1611.02660': 'HRDH\\train\\1611.02660.json',
#  '1611.03321': 'HRDH\\train\\1611.03321.json',
#  '1611.04145': 'HRDH\\train\\1611.04145.json',
#  '1611.04833': 'HRDH\\train\\1611.04833.json',
#  '1611.04955': 'HRDH\\train\\1611.04955.json',
#  '1611.05845': 'HRDH\\train\\1611.05845.json',
#  '1611.06678': 'HRDH\\train\\1611.06678.json',
#  '1611.07100': 'HRDH\\train\\1611.07100.json',
#  '1611.07612': 'HRDH\\train\\1611.07612.json',
#  '1611.07850': 'HRDH\\train\\1611.07850.json',
#  '1611.08134': 'HRDH\\train\\1611.08134.json',
#  '1611.08258': 'HRDH\\train\\1611.08258.json',
#  '1611.09160': 'HRDH\\train\\1611.09160.json',
#  '1612.00066': 'HRDH\\train\\1612.00066.json',
#  '1612.00575': 'HRDH\\train\\1612.00575.json',
#  '1612.00991': 'HRDH\\train\\1612.00991.json',
#  '1612.01553': 'HRDH\\train\\1612.01553.json',
#  '1612.01870': 'HRDH\\train\\1612.01870.json',
#  '1612.02028': 'HRDH\\train\\1612.02028.json',
#  '1612.02043': 'HRDH\\train\\1612.02043.json',
#  '1612.02106': 'HRDH\\train\\1612.02106.json',
#  '1612.02160': 'HRDH\\train\\1612.02160.json',
#  '1612.02495': 'HRDH\\train\\1612.02495.json',
#  '1612.02564': 'HRDH\\train\\1612.02564.json',
#  '1612.03278': 'HRDH\\train\\1612.03278.json',
#  '1612.03361': 'HRDH\\train\\1612.03361.json',
#  '1612.04496': 'HRDH\\train\\1612.04496.json',
#  '1612.04531': 'HRDH\\train\\1612.04531.json',
#  '1612.04795': 'HRDH\\train\\1612.04795.json',
#  '1612.05890': 'HRDH\\train\\1612.05890.json',
#  '1612.07273': 'HRDH\\train\\1612.07273.json',
#  '1612.07568': 'HRDH\\train\\1612.07568.json',
#  '1612.08388': 'HRDH\\train\\1612.08388.json',
#  '1612.08634': 'HRDH\\train\\1612.08634.json',
#  '1612.08966': 'HRDH\\train\\1612.08966.json',
#  '1701.00260': 'HRDH\\train\\1701.00260.json',
#  '1701.00999': 'HRDH\\train\\1701.00999.json',
#  '1701.01544': 'HRDH\\train\\1701.01544.json',
#  '1701.01574': 'HRDH\\train\\1701.01574.json',
#  '1701.03913': 'HRDH\\train\\1701.03913.json',
#  '1701.04597': 'HRDH\\train\\1701.04597.json',
#  '1701.05019': 'HRDH\\train\\1701.05019.json',
#  '1701.05828': 'HRDH\\train\\1701.05828.json',
#  '1701.06485': 'HRDH\\train\\1701.06485.json',
#  '1701.06559': 'HRDH\\train\\1701.06559.json',
#  '1701.06632': 'HRDH\\train\\1701.06632.json',
#  '1701.06890': 'HRDH\\train\\1701.06890.json',
#  '1701.07222': 'HRDH\\train\\1701.07222.json',
#  '1701.07681': 'HRDH\\train\\1701.07681.json',
#  '1701.08118': 'HRDH\\train\\1701.08118.json',
#  '1701.08291': 'HRDH\\train\\1701.08291.json',
#  '1701.08524': 'HRDH\\train\\1701.08524.json',
#  '1701.09092': 'HRDH\\train\\1701.09092.json',
#  '1702.01583': 'HRDH\\train\\1702.01583.json',
#  '1702.02258': 'HRDH\\train\\1702.02258.json',
#  '1702.02399': 'HRDH\\train\\1702.02399.json',
#  '1702.02528': 'HRDH\\train\\1702.02528.json',
#  '1702.02671': 'HRDH\\train\\1702.02671.json',
#  '1702.02850': 'HRDH\\train\\1702.02850.json',
#  '1702.04463': 'HRDH\\train\\1702.04463.json',
#  '1702.04479': 'HRDH\\train\\1702.04479.json',
#  '1702.04603': 'HRDH\\train\\1702.04603.json',
#  '1702.04779': 'HRDH\\train\\1702.04779.json',
#  '1702.04938': 'HRDH\\train\\1702.04938.json',
#  '1702.05005': 'HRDH\\train\\1702.05005.json',
#  '1702.05291': 'HRDH\\train\\1702.05291.json',
#  '1702.05398': 'HRDH\\train\\1702.05398.json',
#  '1702.05427': 'HRDH\\train\\1702.05427.json',
#  '1702.06355': 'HRDH\\train\\1702.06355.json',
#  '1702.06449': 'HRDH\\train\\1702.06449.json',
#  '1702.06890': 'HRDH\\train\\1702.06890.json',
#  '1702.07210': 'HRDH\\train\\1702.07210.json',
#  '1702.07651': 'HRDH\\train\\1702.07651.json',
#  '1702.07948': 'HRDH\\train\\1702.07948.json',
#  '1702.08634': 'HRDH\\train\\1702.08634.json',
#  '1703.00173': 'HRDH\\train\\1703.00173.json',
#  '1703.00268': 'HRDH\\train\\1703.00268.json',
#  '1703.01089': 'HRDH\\train\\1703.01089.json',
#  '1703.02859': 'HRDH\\train\\1703.02859.json',
#  '1703.03860': 'HRDH\\train\\1703.03860.json',
#  '1703.04225': 'HRDH\\train\\1703.04225.json',
#  '1703.04844': 'HRDH\\train\\1703.04844.json',
#  '1703.05681': 'HRDH\\train\\1703.05681.json',
#  '1703.05991': 'HRDH\\train\\1703.05991.json',
#  '1703.06208': 'HRDH\\train\\1703.06208.json',
#  '1703.06492': 'HRDH\\train\\1703.06492.json',
#  '1703.06697': 'HRDH\\train\\1703.06697.json',
#  '1703.06826': 'HRDH\\train\\1703.06826.json',
#  '1703.07686': 'HRDH\\train\\1703.07686.json',
#  '1703.08179': 'HRDH\\train\\1703.08179.json',
#  '1703.09316': 'HRDH\\train\\1703.09316.json',
#  '1703.09835': 'HRDH\\train\\1703.09835.json',
#  '1703.10389': 'HRDH\\train\\1703.10389.json',
#  '1703.10666': 'HRDH\\train\\1703.10666.json',
#  '1704.00380': 'HRDH\\train\\1704.00380.json',
#  '1704.00706': 'HRDH\\train\\1704.00706.json',
#  '1704.00982': 'HRDH\\train\\1704.00982.json',
#  '1704.01429': 'HRDH\\train\\1704.01429.json',
#  '1704.02272': 'HRDH\\train\\1704.02272.json',
#  '1704.02278': 'HRDH\\train\\1704.02278.json',
#  '1704.03243': 'HRDH\\train\\1704.03243.json',
#  '1704.03949': 'HRDH\\train\\1704.03949.json',
#  '1704.05434': 'HRDH\\train\\1704.05434.json',
#  '1704.06070': 'HRDH\\train\\1704.06070.json',
#  '1704.06743': 'HRDH\\train\\1704.06743.json',
#  '1704.09021': 'HRDH\\train\\1704.09021.json',
#  '1705.00597': 'HRDH\\train\\1705.00597.json',
#  '1705.00699': 'HRDH\\train\\1705.00699.json',
#  '1705.03182': 'HRDH\\train\\1705.03182.json',
#  '1705.04320': 'HRDH\\train\\1705.04320.json',
#  '1705.05414': 'HRDH\\train\\1705.05414.json',
#  '1705.05460': 'HRDH\\train\\1705.05460.json',
#  '1705.05832': 'HRDH\\train\\1705.05832.json',
#  '1705.07962': 'HRDH\\train\\1705.07962.json',
#  '1705.08606': 'HRDH\\train\\1705.08606.json',
#  '1705.08856': 'HRDH\\train\\1705.08856.json',
#  '1705.08870': 'HRDH\\train\\1705.08870.json',
#  '1705.08922': 'HRDH\\train\\1705.08922.json',
#  '1705.09433': 'HRDH\\train\\1705.09433.json',
#  '1705.09769': 'HRDH\\train\\1705.09769.json',
#  '1705.09772': 'HRDH\\train\\1705.09772.json',
#  '1705.10535': 'HRDH\\train\\1705.10535.json',
#  '1705.10557': 'HRDH\\train\\1705.10557.json',
#  '1705.10561': 'HRDH\\train\\1705.10561.json',
#  '1705.10899': 'HRDH\\train\\1705.10899.json',
#  '1706.00098': 'HRDH\\train\\1706.00098.json',
#  '1706.01071': 'HRDH\\train\\1706.01071.json',
#  '1706.01679': 'HRDH\\train\\1706.01679.json',
#  '1706.02024': 'HRDH\\train\\1706.02024.json',
#  '1706.03077': 'HRDH\\train\\1706.03077.json',
#  '1706.03268': 'HRDH\\train\\1706.03268.json',
#  '1706.03992': 'HRDH\\train\\1706.03992.json',
#  '1706.04572': 'HRDH\\train\\1706.04572.json',
#  '1706.04971': 'HRDH\\train\\1706.04971.json',
#  '1706.05209': 'HRDH\\train\\1706.05209.json',
#  '1706.06307': 'HRDH\\train\\1706.06307.json',
#  '1706.06799': 'HRDH\\train\\1706.06799.json',
#  '1706.07361': 'HRDH\\train\\1706.07361.json',
#  '1706.08307': 'HRDH\\train\\1706.08307.json',
#  '1706.08414': 'HRDH\\train\\1706.08414.json',
#  '1706.09134': 'HRDH\\train\\1706.09134.json',
#  '1706.09269': 'HRDH\\train\\1706.09269.json',
#  '1706.09534': 'HRDH\\train\\1706.09534.json',
#  '1706.09911': 'HRDH\\train\\1706.09911.json',
#  '1707.00162': 'HRDH\\train\\1707.00162.json',
#  '1707.00163': 'HRDH\\train\\1707.00163.json',
#  '1707.00359': 'HRDH\\train\\1707.00359.json',
#  '1707.00703': 'HRDH\\train\\1707.00703.json',
#  '1707.00757': 'HRDH\\train\\1707.00757.json',
#  '1707.00852': 'HRDH\\train\\1707.00852.json',
#  '1707.01056': 'HRDH\\train\\1707.01056.json',
#  '1707.01308': 'HRDH\\train\\1707.01308.json',
#  '1707.01355': 'HRDH\\train\\1707.01355.json',
#  '1707.02518': 'HRDH\\train\\1707.02518.json',
#  '1707.02554': 'HRDH\\train\\1707.02554.json',
#  '1707.02690': 'HRDH\\train\\1707.02690.json',
#  '1707.03360': 'HRDH\\train\\1707.03360.json',
#  '1707.03363': 'HRDH\\train\\1707.03363.json',
#  '1707.03547': 'HRDH\\train\\1707.03547.json',
#  '1707.03762': 'HRDH\\train\\1707.03762.json',
#  '1707.04304': 'HRDH\\train\\1707.04304.json',
#  '1707.04480': 'HRDH\\train\\1707.04480.json',
#  '1707.04651': 'HRDH\\train\\1707.04651.json',
#  '1707.04877': 'HRDH\\train\\1707.04877.json',
#  '1707.05357': 'HRDH\\train\\1707.05357.json',
#  '1707.05949': 'HRDH\\train\\1707.05949.json',
#  '1707.06163': 'HRDH\\train\\1707.06163.json',
#  '1707.06184': 'HRDH\\train\\1707.06184.json',
#  '1707.06231': 'HRDH\\train\\1707.06231.json',
#  '1707.06468': 'HRDH\\train\\1707.06468.json',
#  '1707.06480': 'HRDH\\train\\1707.06480.json',
#  '1707.06799': 'HRDH\\train\\1707.06799.json',
#  '1707.06854': 'HRDH\\train\\1707.06854.json',
#  '1707.06945': 'HRDH\\train\\1707.06945.json',
#  '1707.07129': 'HRDH\\train\\1707.07129.json',
#  '1707.07297': 'HRDH\\train\\1707.07297.json',
#  '1707.07763': 'HRDH\\train\\1707.07763.json',
#  '1707.08134': 'HRDH\\train\\1707.08134.json',
#  '1707.08435': 'HRDH\\train\\1707.08435.json',
#  '1707.08474': 'HRDH\\train\\1707.08474.json',
#  '1707.09861': 'HRDH\\train\\1707.09861.json',
#  '1707.09913': 'HRDH\\train\\1707.09913.json',
#  '1708.00201': 'HRDH\\train\\1708.00201.json',
#  '1708.01139': 'HRDH\\train\\1708.01139.json',
#  '1708.01358': 'HRDH\\train\\1708.01358.json',
#  '1708.01894': 'HRDH\\train\\1708.01894.json',
#  '1708.03767': 'HRDH\\train\\1708.03767.json',
#  '1708.04585': 'HRDH\\train\\1708.04585.json',
#  '1708.05286': 'HRDH\\train\\1708.05286.json',
#  '1708.05695': 'HRDH\\train\\1708.05695.json',
#  '1708.06520': 'HRDH\\train\\1708.06520.json',
#  '1708.07012': 'HRDH\\train\\1708.07012.json',
#  ...}
